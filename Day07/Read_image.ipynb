# %%
from IPython.display import Image
Image("https://mars.nasa.gov/mars2020-raw-images/pub/ods/surface/sol/00002/ids/fdr/browse/zcam/ZRF_0002_0667131195_000FDR_N0010052AUT_04096_0260LUJ01_1200.jpg")


#more : https://anvil.works/blog/photos-from-mars
